# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * The temperature for over 500 randomly selected cities ranged from just over 100 degrees to below -40 degrees on 12/6/2018.
# * Cities with the warmest temperatures are closest to the equator (0 degrees latitude).  Almost all of the cities that fall within 20 degrees of the equator have a temperatures of 40 degrees and above at this time of year.
# * The cities with the highest wind speeds were found in the northern hemisphere.
# * Humidity and cloudiness were evenly distributed between cities in both northern and southern hemispheres.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import datetime
from ratelimit import limits, sleep_and_retry
import seaborn as sns

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
weather_df = pd.DataFrame()

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Print a log of each city as it's being processed with the city number and city name.

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# Set up DataFrame
column_names = ["Cloudiness","Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed"]
weather_df = pd.DataFrame(index=cities, columns=column_names)

# Set up Datestamp 
current_date = datetime.datetime.today().strftime('%m-%d-%Y')

# Set limits for calling API
minute = 60
@sleep_and_retry
@limits(calls=50, period=minute)

# Function to get weather data and save to a DataFrame
def call_api(url):
    response = requests.get(url).json()
    weather_df.loc[city, "Cloudiness"] = response["clouds"]["all"]
    weather_df.loc[city, "Country"] = response["sys"]["country"]
    weather_df.loc[city, "Date"] = response["dt"]
    weather_df.loc[city, "Humidity"] = response["main"]["humidity"]
    weather_df.loc[city, "Lat"] = response["coord"]["lat"]
    weather_df.loc[city, "Lng"] = response["coord"]["lon"]
    weather_df.loc[city, "Max Temp"] = response["main"]["temp_max"]
    weather_df.loc[city, "Wind Speed"] = response["wind"]["speed"]
    print(f"Processing Record {idx} | {city}")
    return

# Get weather data for cities
for idx, city in enumerate(cities):
    try:
        call_api(query_url + city)
    except:
        print("City not found. Skipping...")
# Out:
# Processing Record 0 | nikolskoye
# Processing Record 1 | torbay
# Processing Record 2 | albany
# Processing Record 3 | vaini
# Processing Record 4 | mayumba
# Processing Record 5 | cape town
# Processing Record 6 | busselton
# Processing Record 7 | rikitea
# Processing Record 8 | tiksi
# Processing Record 9 | ushuaia
# Processing Record 10 | launceston
# Processing Record 11 | severo-kurilsk
# Processing Record 12 | barrow
# Processing Record 13 | lebu
# Processing Record 14 | norman wells
# Processing Record 15 | black river
# Processing Record 16 | victoria
# Processing Record 17 | atuona
# Processing Record 18 | chincholi
# Processing Record 19 | carnarvon
# Processing Record 20 | tazovskiy
# Processing Record 21 | sur
# Processing Record 22 | mataura
# Processing Record 23 | avarua
# Processing Record 24 | aykhal
# Processing Record 25 | novyy svit
# Processing Record 26 | pisco
# Processing Record 27 | castro
# Processing Record 28 | saiha
# Processing Record 29 | georgetown
# ...

# %% [markdown]
# ### Export the data to a .csv and display the DataFrame count

# %%
clean_weather_df = weather_df.dropna(how='any')
clean_weather_df.to_csv(output_data_file, header=True)
clean_weather_df.count()
# Out:
# Cloudiness    549
# Country       549
# Date          549
# Humidity      549
# Lat           549
# Lng           549
# Max Temp      549
# Wind Speed    549
# dtype: int64

# %% [markdown]
# ### Display the DataFrame

# %%
clean_weather_df.head()
# Out:
#            Cloudiness Country        Date Humidity    Lat    Lng Max Temp  \
# nikolskoye         90      RU  1544149800       96   59.7  30.79     33.8
# torbay             90      CA  1544148000       92  47.66 -52.73     28.4
# albany             90      US  1544151480       56  42.65 -73.75    35.06
# vaini              20      IN  1544148000      100  15.34  74.49     66.2
# mayumba            92      GA  1544151963      100  -3.44  10.65    77.96
#
#            Wind Speed
# nikolskoye       4.47
# torbay          38.03
# albany           9.17
# vaini            3.74
# mayumba          3.85

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
# Latitude vs. Max Temperature Plot
fig, ax = plt.subplots()
ax.scatter(clean_weather_df['Lat'],clean_weather_df['Max Temp'], marker='o', facecolors='blue', edgecolors='black')
ax.set_xlabel("Latitude")
ax.set_ylabel("Max Temperture (F)")
ax.set_title(f"City Latitude vs. Max Temp ({current_date})")
ax.grid(axis='both',color='white')
sns.set_style('darkgrid')

# Save plot
fig.savefig("Images/latitute_max_temp.png")

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
# Latitude vs. Humidity Plot
fig, ax = plt.subplots()
ax.scatter(clean_weather_df['Lat'],clean_weather_df['Humidity'], marker='o', facecolors='blue', edgecolors='black')
ax.set_xlabel("Latitude")
ax.set_ylabel("Humidity (%)")
ax.set_title(f"City Latitude vs. Humidity ({current_date})")
ax.grid(axis='both', color='white')
sns.set_style('darkgrid')

# Save plot
fig.savefig("Images/latitute_humidity.png")

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
# Latitude vs. Cloudiness Plot
fig, ax = plt.subplots()
ax.scatter(clean_weather_df['Lat'],clean_weather_df['Cloudiness'], marker='o', facecolors='blue', edgecolors='black')
ax.set_xlabel("Latitude")
ax.set_ylabel("Cloudiness (%)")
ax.set_title(f"City Latitude vs. Cloudiness ({current_date})")
ax.grid(axis='both', color='white')
sns.set_style('darkgrid')

# Save plot
fig.savefig("Images/latitute_cloudiness.png")

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
# Latitude vs. Wind Speed Plot
fig, ax = plt.subplots()
ax.scatter(clean_weather_df['Lat'],clean_weather_df['Wind Speed'], marker='o', facecolors='blue', edgecolors='black')
ax.set_xlabel("Latitude")
ax.set_ylabel("Wind Speed (mph)")
ax.set_title(f"City Latitude vs. Wind Speed ({current_date})")
ax.grid(axis='both', color='white')
sns.set_style('darkgrid')

# Save plot
fig.savefig("Images/latitute_windspeed.png")
